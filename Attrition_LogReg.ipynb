# %% [markdown]
# # ATTRITION DATASET ANALYSIS

# %%
# loading necessary imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
# Reading the dataset
at = pd.read_csv('Attrition.csv')

# %%
# Checking first 5 records
at.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
at.isnull().sum()  # There is no missing values in the dataset.
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Description of the dataset.
at.describe(include = "all")
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %% [markdown]
# ### Performing Label Encoding on the categorical data

# %%
# Using Label encoding for conversion of object datatypes.
le = LabelEncoder()
at[at.select_dtypes(include = ['object']).columns] = at[at.select_dtypes(include = ['object']).columns].apply(le.fit_transform)

# %%
at.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ### Check for Multicollinearity

# %% [markdown]
# #### 1. Check for multi-collinearity using correlation matrix

# %%
at.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EmployeeCount                  NaN        NaN             NaN        NaN
# EmployeeNumber           -0.010145  -0.010577       -0.015578  -0.050990
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# ...

# %%
at_x = at.drop('Attrition', axis = 1)
at_y = at.iloc[:,1]

# %% [markdown]
# #### 2. Check for multi-collinearity using Variance Inflation factor.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['vif_values'] = [variance_inflation_factor(at_x.values, i) for i in range(at_x.shape[1])]
vif['variables'] = at_x.columns
vif
# Out:
# C:\Users\SOUVIK\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1636: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\SOUVIK\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1636: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#     vif_values                 variables
# 0     2.054226                       Age
# 1     1.016808            BusinessTravel
# 2     1.026401                 DailyRate
# 3     1.942165                Department
# 4     1.018096          DistanceFromHome
# 5     1.065295                 Education
# 6     1.016240            EducationField
# 7     0.000000             EmployeeCount
# 8     1.022699            EmployeeNumber
# 9     1.018022   EnvironmentSatisfaction
# 10    1.020038                    Gender
# 11    1.021984                HourlyRate
# 12    1.020836            JobInvolvement
# ...

# %% [markdown]
# ## Applying Logistis Regression Model
#
# Consider the Attrition column as the target variable

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
at_x_train,at_x_test, at_y_train, at_y_test = train_test_split(at_x, at_y, test_size = 0.2, random_state = 42)

# %%
log = LogisticRegression()
log.fit(at_x_train, at_y_train)
pred_y = log.predict(at_x_test)
# Out:
# C:\Users\SOUVIK\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Confusion Matrix

# %%
tab1 = confusion_matrix(at_y_test, pred_y)  # Here predicted comes to the top and actual in the left side
tab1
# Out:
# array([[254,   1],
#        [ 27,  12]], dtype=int64)

# %% [markdown]
# ### Accuracy of the model

# %%
Accuracy = tab1.diagonal().sum() * 100 / tab1.sum()
Accuracy
# Out:
# 90.47619047619048

# %% [markdown]
# ### Probability scores for binary classes "Yes" : 1 and "No": 0 for the target (Attrition)

# %%
# Ordering probability of attrition rate (1) in descending order.
#(As there is no ID column in dataset, index can be treated as ID).

pred_proba_df = pd.DataFrame(log.predict_proba(at_x))
pred_proba_df.sort_values(pred_proba_df.index[1], ascending = False)
# Out:
#              0         1
# 798   0.087872  0.912128
# 463   0.098246  0.901754
# 1060  0.131466  0.868534
# 688   0.177276  0.822724
# 748   0.181683  0.818317
# ...        ...       ...
# 417   0.999316  0.000684
# 894   0.999355  0.000645
# 858   0.999405  0.000595
# 1010  0.999481  0.000519
# 716   0.999493  0.000507
#
# [1470 rows x 2 columns]

# %%
log.intercept_  # This shows the intercept of the Logistic Regression model fitted.
# Out:
# array([0.00042136])

# %%
# Co-efficients for the independent variables
beta_df = pd.DataFrame({'Variables':list(at_x.columns), 'beta':list(log.coef_.flatten())}) 
beta_df
# Out:
#                    Variables      beta
# 0                        Age -0.028197
# 1             BusinessTravel -0.005342
# 2                  DailyRate -0.000175
# 3                 Department  0.271941
# 4           DistanceFromHome  0.031965
# 5                  Education  0.061750
# 6             EducationField  0.068531
# 7              EmployeeCount  0.000421
# 8             EmployeeNumber -0.000038
# 9    EnvironmentSatisfaction -0.299286
# 10                    Gender  0.226128
# 11                HourlyRate  0.000804
# 12            JobInvolvement -0.423561
# 13                  JobLevel -0.106840
# 14                   JobRole -0.025387
# 15           JobSatisfaction -0.340331
# 16             MaritalStatus  0.503682
# 17             MonthlyIncome -0.000091
# 18               MonthlyRate  0.000008
# 19        NumCompaniesWorked  0.153806
# 20                    Over18  0.000000
# 21                  OverTime  1.377355
# 22         PercentSalaryHike -0.026026
# ...

# %% [markdown]
# ### AUROC curve

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
roc_auc_value = roc_auc_score(at_y_test, pred_y)
roc_auc_value
# Out:
# 0.6518853695324284

# %%
# Plotting AUROC curve

pred_value_prob = pd.DataFrame(log.predict_proba(at_x_test))
pred_value_prob = pred_value_prob.iloc[:,1] # only selecting the +ve (1/yes) column probabilities.

fpr, tpr, threshold = roc_curve(at_y_test, pred_value_prob)

plt.figure(figsize=(10,10))
plt.plot(fpr,tpr, color = 'r', label="LogisticRegression(area=%.2f)" %roc_auc_value)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUROC ON THE ATTRITION')
plt.legend(loc=1)
plt.grid(linestyle = '--')

# %% [markdown]
# ### F1 score

# %%
# Lets plot Precision-Recall curve

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score

# %%
pred_value = log.predict(at_x_train)
pred_value_prob = log.predict_proba(at_x_train)
pred_value_prob = pd.DataFrame(pred_value_prob)
pred_value_prob1 = pred_value_prob.iloc[:,1]
precision, recall, thresholds = precision_recall_curve(at_y_train, pred_value_prob1)
f1 = f1_score(at_y_train, pred_value)
f1
# Out:
# 0.4551724137931034

# %% [markdown]
# #### From the above score for f1, it is clear that either of the two classes(1 or 0) has a class_Imbalance problem

# %% [markdown]
# ## Here we can see that due to lesser number of positive cases in attrition, class 1 does not
#
# ## get proper representation

# %%
at.Attrition.value_counts()  # So we need to up-sample the class 1.
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
# Percentage of weightage of class 0
per = 1233*100/1470
per
# Out:
# 83.87755102040816

# %%
# Percentage of weightage of class 1
per1 = 237*100/1470
per1
# Out:
# 16.122448979591837

# %% [markdown]
# ### Splitting Dataset into train and test before resolving the Class-Imbalance problem

# %%
at_train, at_test = train_test_split(at, test_size = 0.2, random_state = 10)

# %%
a = at_train[at.Attrition > 0]
a.head()
# Out:
# C:\Users\SOUVIK\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 370    21          1               2        156           2                12
# 1262   43          1               1        807           1                17
# 271    47          1               0        666           1                29
# 667    41          1               2       1085           1                 2
# 1297   26          1               2        920           0                20
#
#       Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 370           3               1              1             494  ...
# 1262          3               5              1            1767  ...
# 271           4               1              1             376  ...
# ...

# %%
a.shape
# Out:
# (182, 35)

# %%
at_train = pd.concat([at_train,a,a,a])

# %%
at_train.Attrition.value_counts()
# Out:
# 0    994
# 1    728
# Name: Attrition, dtype: int64

# %%
at_train.Attrition.value_counts(1)*100   # Percentage weightage of each class after resolving the class-imbalance problem.
# Out:
# 0    57.723577
# 1    42.276423
# Name: Attrition, dtype: float64

# %% [markdown]
# #### From the above observation, it is clear that the class imbalance problem is almost resolved, so refit the model on balanced data.

# %%
at_x_train = at_train.drop('Attrition', axis = 1) # independent variables for training set
at_y_train = at_train.loc[:,'Attrition']  # Target variable for training set

# %%
at_x_test = at_test.drop('Attrition', axis = 1)  # independent variables for testing set
at_y_test = at_test.loc[:,'Attrition']   # Target variable for testing set

# %% [markdown]
# ### Fitting the Logistic Regression model on dataset after resolving Class-Imbalance problem

# %%
log.fit(at_x_train, at_y_train)
# Out:
# C:\Users\SOUVIK\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred_y = log.predict(at_x_test) # predicting on the test data.

# %%
# confusion Matrix

tab_new = confusion_matrix(at_y_test, pred_y)  # Here predicted comes to the top and actual in the left side
tab_new
# Out:
# array([[201,  38],
#        [ 19,  36]], dtype=int64)

# %%
# Accuracy of the model

Accuracy = tab1.diagonal().sum() * 100 / tab1.sum()
Accuracy
# Out:
# 90.47619047619048

# %% [markdown]
# ### Classsification Report

# %%
from sklearn import metrics

print('Report : ')
print(metrics.classification_report(at_y_test, pred_y))
# Out:
# Report :
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.88       239
#            1       0.49      0.65      0.56        55
#
#     accuracy                           0.81       294
#    macro avg       0.70      0.75      0.72       294
# weighted avg       0.83      0.81      0.82       294

# %% [markdown]
# ### AUROC curve

# %%
roc_auc_value = roc_auc_score(at_y_test, pred_y)
roc_auc_value
# Out:
# 0.7477748193229364

# %%
# Plotting AUROC curve after improving class imbalance problem

pred_value_prob = pd.DataFrame(log.predict_proba(at_x_test))
pred_value_prob = pred_value_prob.iloc[:,1] # only selecting the +ve (1/yes) column probabilities.

fpr, tpr, threshold = roc_curve(at_y_test, pred_value_prob)

plt.figure(figsize=(10,10))
plt.plot(fpr,tpr, color = 'r', label="LogisticRegression(area=%.2f)" %roc_auc_value)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('AUROC ON THE ATTRITION')
plt.legend(loc=1)
plt.grid(linestyle = '--')

# %% [markdown]
# #### Here we can observe that the auroc acore has improved from 65% to 75% after resolving class-imbalance problem.

# %%
# Precision-recall after improving class imbalance problem

pred_value = log.predict(at_x_train)
pred_value_prob = log.predict_proba(at_x_train)
pred_value_prob = pd.DataFrame(pred_value_prob)
pred_value_prob1 = pred_value_prob.iloc[:,1]
precision, recall, thresholds = precision_recall_curve(at_y_train, pred_value_prob1)
f1 = f1_score(at_y_train, pred_value)
f1
# Out:
# 0.720112517580872

# %%
# Plotting Precision-recall after improving class imbalance problem

plt.figure(figsize=(10,10))
plt.plot(recall,precision, color = 'r', label="LogisticRegression(area=%.2f)" %f1)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('Precision-Recall ON THE ATTRITION')
plt.legend(loc=1)
plt.grid(linestyle = '--')

# %% [markdown]
# #### Here we can observe that the f1 acore has also improved from 45% to 72% after resolving class-imbalance problem.

# %% [markdown]
# ### There is multicollinearity in Joblevel and MonthlyIncome(as the vif for these are greater than 10, as seen earlier in the vif table).
# #So, lets remove these two columns and implement model.

# %%
at_x_train_new = at_x_train.drop(['JobLevel', 'MonthlyIncome'], axis = 1)

# %%
#at_x_train,at_x_test, at_y_train, at_y_test = train_test_split(at_x1, at_y, test_size = 0.2, random_state = 42)

# %%
log.fit(at_x_train, at_y_train)
# Out:
# C:\Users\SOUVIK\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred_value = log.predict(at_x_test)

# %%
tab2 = confusion_matrix(at_y_test, pred_value)
tab2
# Out:
# array([[201,  38],
#        [ 19,  36]], dtype=int64)

# %%
Accuracy = tab2.diagonal().sum() * 100 / tab1.sum()
Accuracy
# Out:
# 80.61224489795919

# %% [markdown]
# So,we can see from the above that there is change in accuracy (decrease in accuracy) after dropping Joblevel and MonthlyIncome columns.
#
# So, we will not drop these columns having some level of multicollinearity.

# %% [markdown]
# ## Conclusion:-
#
# This dataset has class-imbalance problem which is resolved by up-sampling the class 1 of the target variable, which had lower representation as compared to class 0.
#
# After resolving the problem, it is clear that the accuracy as well as the auroc and f1 scores improved extensively.
#
# Here Logistic Regression model is used on the dataset. We can also implement other classification models like Decision Tree or Random Forest, etc.
